# %% [markdown]
# # Path Planning Testing

# %%
from __init__ import *
import chess
from matplotlib import pyplot as plt
board = WizBoard()
planner = PathPlanner(board)

# %%
def plot_paths(paths:list[Path], title=""):
    plt.figure(figsize=(6,4))
    plt.axis([0,12,0,8])
    plt.xticks(range(0, 13, 2))
    plt.grid(True)
    plt.title(title)
    for path in paths:
        plt.plot([point[0] for point in path.points], [point[1] for point in path.points], 'o')

# %%
move = chess.Move.from_uci('d5f6')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
print(listOfPoints)
plot_paths([Path('', listOfPoints)])
# Out:
# [(3.5, 4.5), (5.5, 4.5), (5.5, 5.5)]

# %%
#Knight Testing

#Normal move (hoirzontal):
move = chess.Move.from_uci('d5f6')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
plot_paths([Path('', listOfPoints)], "Horizontal Knight's Move")

#Normal Move(Vertical):
move = chess.Move.from_uci('d4e6')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
plot_paths([Path('', listOfPoints)], "Vertical Knight's Move")

#Piece in the way
move = chess.Move.from_uci('b1c3')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
plot_paths([Path('', listOfPoints)], "Vertical Obstructed Knight's Move")

move = chess.Move.from_uci('b1d2')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
plot_paths([Path('', listOfPoints)], "Horizontal Obstructed Knight's Move")

# %%
#Leaving Piece Code:

#Leave, exit white side
end_square = 79
start_square = 58
listOfPoints = planner.single_path(start_square, end_square, "LEAVE")
plot_paths([Path('', listOfPoints)], "Leaving White Side 58->79")

#Leave, exit black side
end_square = 68
start_square = 5
listOfPoints = planner.single_path(start_square, end_square, "LEAVE")
plot_paths([Path('', listOfPoints)], "Leaving Black Side 5->68")

# %%
#Castling Test:

#White Side
move = chess.Move.from_uci('h1f1')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "CASTLE")
plot_paths([Path('', listOfPoints)])

#Black Side
move = chess.Move.from_uci('a8c8')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "CASTLE")
plot_paths([Path('', listOfPoints)])

# %%
#Normal Movement Test:

#Straight Line
move = chess.Move.from_uci('a1a8')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
plot_paths([Path('', listOfPoints)])

#Diagonal
move = chess.Move.from_uci('a3f8')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
plot_paths([Path('', listOfPoints)])

# %%
move = chess.Move.from_uci('b1c3')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
#points = planner.turn_paths(chess.Move.from_uci('b1c3'))
# Plotting
plot_paths([Path('', listOfPoints)])


move = chess.Move.from_uci('c3d5')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
#points = planner.turn_paths(chess.Move.from_uci('b1c3'))

# Plotting
plot_paths([Path('', listOfPoints)])

# %%
board.push(chess.Move.from_uci('b1c3'))
board.push(chess.Move.from_uci('d7d5'))

print(board)
paths = planner.turn_paths(chess.Move.from_uci('c3d5'))
print(paths)
plot_paths(paths)
board.push(chess.Move.from_uci('c3d5'))
print('')
print(board)
print(board.piece_list)
paths = planner.turn_paths(chess.Move.from_uci('d8d5'))
print(paths)
plot_paths(paths)
# Out:
# r n b q k b n r
# p p p . p p p p
# . . . . . . . .
# . . . p . . . .
# . . . . . . . .
# . . N . . . . .
# P P P P P P P P
# R . B Q K B N R
# [N1: [(2.5, 2.5), (2.5, 4.5), (3, 4.5)], p4: [(3.5, 4), (8, 4), (8, 0.5), (8.5, 0.5)], N1: [(3.5, 4.5), (3.5, 4.5)]]
#
# r n b q k b n r
# p p p . p p p p
# . . . . . . . .
# . . . N . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R . B Q K B N R
# ['R1', '', 'B1', 'Q', 'K', 'B2', 'N2', 'R2', 'P1', 'P1', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'N1', '', '', '', '', '', '', '', '', '', '', '', '', 'p1', 'p2', 'p3', '', 'p5', 'p6', 'p7', 'p8', 'r1', 'n1', 'b1', 'q', 'k', 'b2', 'n2', 'r2', 'p4', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# [q: [(3.5, 7.5), (3.5, 5)], N1: [(3.5, 4), (8, 4), (8, 7.5), (8.5, 7.5)], q: [(3.5, 4.5), (3.5, 4.5)]]
