# %% [markdown]
# # Path Planning Testing

# %%
from __init__ import *
import chess
from matplotlib import pyplot as plt
board = WizBoard()
planner = PathPlanner(board)

# %%
def plot_paths(paths:list[Path], title=""):
    plt.figure(figsize=(6,4))
    plt.axis([0,12,0,8])
    plt.xticks(range(13))
    plt.grid(True)
    plt.title(title)
    for path in paths:
        plt.plot([point[0] for point in path.points], [point[1] for point in path.points], 'o')

# %%
move = chess.Move.from_uci('d5f6')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
plot_paths([Path('', listOfPoints)])

# %%
#Knight Testing

#Normal move (hoirzontal):
move = chess.Move.from_uci('d5f6')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
plot_paths([Path('', listOfPoints)], "Horizontal Knight's Move")

#Normal Move(Vertical):
move = chess.Move.from_uci('d4e6')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
plot_paths([Path('', listOfPoints)], "Vertical Knight's Move")

#Piece in the way
move = chess.Move.from_uci('b1c3')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
print(f"List: {listOfPoints}")
plot_paths([Path('', listOfPoints)], "Vertical Obstructed Knight's Move")
# Out:
# List: [(2, 0.5), (2, 2.5), (2.5, 2.5)]

# %%
#Leaving Piece Code:

#Leave, exit white side
end_square = 79
start_square = 58
listOfPoints = planner.single_path(start_square, end_square, "LEAVE")
plot_paths([Path('', listOfPoints)], "Leaving White Side 58->95")

#Leave, exit black side
end_square = 68
start_square = 5
listOfPoints = planner.single_path(start_square, end_square, "LEAVE")
plot_paths([Path('', listOfPoints)], "Leaving Black Side 5->68")

# %%
#Castling Test:

#White Side
move = chess.Move.from_uci('h1f1')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "CASTLE")
plot_paths([Path('', listOfPoints)])

#Black Side
move = chess.Move.from_uci('a8c8')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "CASTLE")
plot_paths([Path('', listOfPoints)])

# %%
#Normal Movement Test:

#Straight Line
move = chess.Move.from_uci('a1a8')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
plot_paths([Path('', listOfPoints)])

#Diagonal
move = chess.Move.from_uci('a3f8')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
plot_paths([Path('', listOfPoints)])

# %%
move = chess.Move.from_uci('b1c3')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
#points = planner.turn_paths(chess.Move.from_uci('b1c3'))
# Plotting
plot_paths([Path('', listOfPoints)])


move = chess.Move.from_uci('c3d5')
end_square = move.to_square
start_square = move.from_square
listOfPoints = planner.single_path(start_square, end_square, "NORMAL")
#points = planner.turn_paths(chess.Move.from_uci('b1c3'))

# Plotting
plot_paths([Path('', listOfPoints)])

# %%
board.push(chess.Move.from_uci('b1c3'))
board.push(chess.Move.from_uci('d7d5'))

print(board)
plot_paths(planner.turn_paths(chess.Move.from_uci('c3d5')))
board.push(chess.Move.from_uci('c3d5'))
print('')
print(board)
print(board.piece_list)
plot_paths(planner.turn_paths(chess.Move.from_uci('d8d5')))
# Out:
# r n b q k b n r
# p p p . p p p p
# . . . . . . . .
# . . . p . . . .
# . . . . . . . .
# . . N . . . . .
# P P P P P P P P
# R . B Q K B N R
#
# r n b q k b n r
# p p p . p p p p
# . . . . . . . .
# . . . N . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R . B Q K B N R
# [<robot_control.Robot object at 0x000001AC86EBF590>, None, <robot_control.Robot object at 0x000001AC86AF1390>, <robot_control.Robot object at 0x000001AC86EBF450>, <robot_control.Robot object at 0x000001AC86C54610>, <robot_control.Robot object at 0x000001AC86E3EF50>, <robot_control.Robot object at 0x000001ACF7B54650>, <robot_control.Robot object at 0x000001ACF7B54690>, <robot_control.Robot object at 0x000001ACF7B548D0>, <robot_control.Robot object at 0x000001ACF7C97D10>, <robot_control.Robot object at 0x000001ACF7B543D0>, <robot_control.Robot object at 0x000001ACF7B54050>, <robot_control.Robot object at 0x000001AC868AB890>, <robot_control.Robot object at 0x000001AC8688CA10>, <robot_control.Robot object at 0x000001AC8688CA50>, <robot_control.Robot object at 0x000001AC8688CA90>, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, <robot_control.Robot object at 0x000001AC86EAC410>, None, None, None, None, None, None, None, None, None, None, None, None, <robot_control.Robot object at 0x000001AC8688CAD0>, <robot_control.Robot object at 0x000001AC8688CB10>, <robot_control.Robot object at 0x000001AC8688CB50>, None, <robot_control.Robot object at 0x000001AC86F7E210>, <robot_control.Robot object at 0x000001AC86F7E250>, <robot_control.Robot object at 0x000001AC86F7E290>, <robot_control.Robot object at 0x000001AC86F7E2D0>, <robot_control.Robot object at 0x000001AC86F7E390>, <robot_control.Robot object at 0x000001AC86F7E3D0>, <robot_control.Robot object at 0x000001AC86F7E350>, <robot_control.Robot object at 0x000001AC86F7E410>, <robot_control.Robot object at 0x000001AC86F7E490>, <robot_control.Robot object at 0x000001AC86F7E510>, <robot_control.Robot object at 0x000001AC86F7E810>, <robot_control.Robot object at 0x000001AC86F7E6D0>, <robot_control.Robot object at 0x000001AC86F7E1D0>, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
